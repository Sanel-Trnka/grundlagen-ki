# %% [markdown]
# # Constraint Satisfaction Problem
#
# ## Aufgabe:
# ### Labor- und Präsentationsplanung als Constraint Satisfaction Problem (CSP)

# %% [markdown]
# ### CSP-Konfiguration laden und darstellen
#
# Tragen Sie den Namen des Konfigurationsfiles ein. Dieses wird kurz analysiert und dargestellt. Danach können Sie es geeignet dem CSP übergeben.

# %%
from csp_utils import analyze_and_display

# %%
# Ihr Dateiname - nacheinander mehrere Konfigurationen testen und analysieren.

analyze_and_display("configC.json")
# Out:
# # CSP-Konfiguration
# Verwendete Datei: C:\Users\flore\Documents\GitHub\grundlagen-ki\constraints\C4\C4\configC.json
# Lademodus: json
# ## Übersicht
# Gruppen:
#   G1, G2, G3, G4, G5, G6, G7, G8, G9, G10
# Tage:
#   Mon, Tue, Wed, Thu, Fri
# Zeitslots:
#   1: 08:00–10:00
#   2: 10:30–12:30
#   3: 13:00–14:30
#   4: 15:00–17:00
# Räume:
#   L1, L2, L3
# Anzahl Kommissionen:
#   3
# Anzahl Verfügbarkeits-Einträge:
#   45
# ## Kompetenzen der Kommissionen
#   Kommission Themen  A  B  C
# 0         K1   A, B  ✓  ✓
# 1         K2      A  ✓
# 2         K3   A, C  ✓     ✓
# ## Legende
# <style type="text/css">
# #T_75952_row0_col0, #T_75952_row1_col0, #T_75952_row2_col0 {
#   font-weight: bold;
# }
# #T_75952_row0_col1 {
#   background-color: #fde2e4;
# }
# #T_75952_row1_col1 {
#   background-color: #e2f0cb;
# }
# #T_75952_row2_col1 {
#   background-color: #cddafd;
# }
# </style>
# <table id="T_75952">
#   <thead>
#     <tr>
#       <th id="T_75952_level0_col0" class="col_heading level0 col0" >Kommission</th>
#       <th id="T_75952_level0_col1" class="col_heading level0 col1" >Farbe</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_75952_row0_col0" class="data row0 col0" >K1</td>
#       <td id="T_75952_row0_col1" class="data row0 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_75952_row1_col0" class="data row1 col0" >K2</td>
#       <td id="T_75952_row1_col1" class="data row1 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_75952_row2_col0" class="data row2 col0" >K3</td>
#       <td id="T_75952_row2_col1" class="data row2 col1" ></td>
#     </tr>
#   </tbody>
# </table>
# ## Wochenplan der Verfügbarkeiten
# <style type="text/css">
# #T_bbc01 th {
#   text-align: center;
# }
# #T_bbc01 td {
#   min-width: 180px;
#   height: 42px;
# }
# #T_bbc01_row0_col0, #T_bbc01_row1_col0, #T_bbc01_row2_col0, #T_bbc01_row3_col0 {
#   background-color: #cddafd;
#   text-align: center;
#   white-space: pre-wrap;
#   font-weight: bold;
# }
# #T_bbc01_row0_col1, #T_bbc01_row2_col3, #T_bbc01_row3_col3 {
#   background: linear-gradient(90deg, #e2f0cb 0.00% 50.00%, #cddafd 50.00% 100.00%);
#   text-align: center;
#   white-space: pre-wrap;
#   font-weight: bold;
# }
# #T_bbc01_row0_col2, #T_bbc01_row0_col3, #T_bbc01_row1_col1, #T_bbc01_row1_col2, #T_bbc01_row1_col3, #T_bbc01_row2_col1, #T_bbc01_row2_col2, #T_bbc01_row3_col1, #T_bbc01_row3_col2 {
#   background: linear-gradient(90deg, #fde2e4 0.00% 33.33%, #e2f0cb 33.33% 66.67%, #cddafd 66.67% 100.00%);
#   text-align: center;
#   white-space: pre-wrap;
#   font-weight: bold;
# }
# #T_bbc01_row0_col4, #T_bbc01_row1_col4, #T_bbc01_row2_col4, #T_bbc01_row3_col4 {
#   background: linear-gradient(90deg, #fde2e4 0.00% 50.00%, #e2f0cb 50.00% 100.00%);
#   text-align: center;
#   white-space: pre-wrap;
#   font-weight: bold;
# }
# </style>
# <table id="T_bbc01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbc01_level0_col0" class="col_heading level0 col0" >Mon</th>
#       <th id="T_bbc01_level0_col1" class="col_heading level0 col1" >Tue</th>
#       <th id="T_bbc01_level0_col2" class="col_heading level0 col2" >Wed</th>
#       <th id="T_bbc01_level0_col3" class="col_heading level0 col3" >Thu</th>
#       <th id="T_bbc01_level0_col4" class="col_heading level0 col4" >Fri</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Zeitslot</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbc01_level0_row0" class="row_heading level0 row0" >1 (08:00–10:00)</th>
#       <td id="T_bbc01_row0_col0" class="data row0 col0" >K3</td>
#       <td id="T_bbc01_row0_col1" class="data row0 col1" >K2, K3</td>
#       <td id="T_bbc01_row0_col2" class="data row0 col2" >K1, K2, K3</td>
#       <td id="T_bbc01_row0_col3" class="data row0 col3" >K1, K2, K3</td>
#       <td id="T_bbc01_row0_col4" class="data row0 col4" >K1, K2</td>
#     </tr>
#     <tr>
#       <th id="T_bbc01_level0_row1" class="row_heading level0 row1" >2 (10:30–12:30)</th>
#       <td id="T_bbc01_row1_col0" class="data row1 col0" >K3</td>
#       <td id="T_bbc01_row1_col1" class="data row1 col1" >K1, K2, K3</td>
#       <td id="T_bbc01_row1_col2" class="data row1 col2" >K1, K2, K3</td>
#       <td id="T_bbc01_row1_col3" class="data row1 col3" >K1, K2, K3</td>
#       <td id="T_bbc01_row1_col4" class="data row1 col4" >K1, K2</td>
#     </tr>
#     <tr>
#       <th id="T_bbc01_level0_row2" class="row_heading level0 row2" >3 (13:00–14:30)</th>
#       <td id="T_bbc01_row2_col0" class="data row2 col0" >K3</td>
#       <td id="T_bbc01_row2_col1" class="data row2 col1" >K1, K2, K3</td>
#       <td id="T_bbc01_row2_col2" class="data row2 col2" >K1, K2, K3</td>
#       <td id="T_bbc01_row2_col3" class="data row2 col3" >K2, K3</td>
#       <td id="T_bbc01_row2_col4" class="data row2 col4" >K1, K2</td>
#     </tr>
#     <tr>
#       <th id="T_bbc01_level0_row3" class="row_heading level0 row3" >4 (15:00–17:00)</th>
#       <td id="T_bbc01_row3_col0" class="data row3 col0" >K3</td>
#       <td id="T_bbc01_row3_col1" class="data row3 col1" >K1, K2, K3</td>
#       <td id="T_bbc01_row3_col2" class="data row3 col2" >K1, K2, K3</td>
#       <td id="T_bbc01_row3_col3" class="data row3 col3" >K2, K3</td>
#       <td id="T_bbc01_row3_col4" class="data row3 col4" >K1, K2</td>
#     </tr>
#   </tbody>
# </table>
# {'groups': ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10'],
#  'days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
#  'timeslots': {'1': '08:00–10:00',
#   '2': '10:30–12:30',
#   '3': '13:00–14:30',
#   '4': '15:00–17:00'},
#  'rooms': ['L1', 'L2', 'L3'],
#  'commissions': {'K1': ['A', 'B'], 'K2': ['A'], 'K3': ['A', 'C']},
#  'availability': {'K1': [['Tue', 2],
#    ['Tue', 3],
#    ['Tue', 4],
#    ['Wed', 1],
#    ['Wed', 2],
#    ['Wed', 3],
#    ['Wed', 4],
#    ['Thu', 1],
#    ['Thu', 2],
#    ['Fri', 1],
#    ['Fri', 2],
#    ['Fri', 3],
#    ['Fri', 4]],
#   'K2': [['Tue', 1],
#    ['Tue', 2],
#    ['Tue', 3],
#    ['Tue', 4],
#    ['Wed', 1],
#    ['Wed', 2],
#    ['Wed', 3],
#    ['Wed', 4],
#    ['Thu', 1],
#    ['Thu', 2],
#    ['Thu', 3],
#    ['Thu', 4],
#    ['Fri', 1],
#    ['Fri', 2],
#    ['Fri', 3],
#    ['Fri', 4]],
#   'K3': [['Mon', 1],
#    ['Mon', 2],
#    ['Mon', 3],
#    ['Mon', 4],
#    ['Tue', 1],
#    ['Tue', 2],
#    ['Tue', 3],
#    ['Tue', 4],
#    ['Wed', 1],
#    ['Wed', 2],
#    ['Wed', 3],
#    ['Wed', 4],
#    ['Thu', 1],
#    ['Thu', 2],
#    ['Thu', 3],
#    ['Thu', 4]]}}

# %% [markdown]
# ## Definition des Constraint Problems
#
# Sie können die Bibliothek aus der Vorlesung nutzen, aber auch andere, z.B. diese:
#
# | Bibliothek            | Vorteile |
# |----------------------|---------|
# | python-constraint    | Sehr einfach zu nutzen, ideal für klassische CSPs, perfekt für einfache Einführungsaufgaben |
# | Google OR-Tools      | Sehr leistungsfähig, unterstützt komplexe Optimierung und Scheduling, industrieller Standard |
# | Pyomo                | Saubere mathematische Modellierung, gut für lineare und ganzzahlige Optimierung |
# | MiniZinc             | Speziell für Constraint-Probleme entwickelt, klare und strukturierte Modellierung |

# %% [markdown]
# ## Ausführen und Ergebnisanalyse
#
# Implementieren. Begründen. Testen. Interpretieren.

# %% [markdown]
# ## Constraint Validator
# Implementieren. Prüfen. Begründen und interpretieren.
